# %% [markdown]
# # Étape 1 — Vérification de l'environnement
#
# Vérifie que les imports clés du POC RAG (FAISS, LangChain, Mistral, FastAPI) fonctionnent dans l'environnement `uv` du projet.

# %%
import sys

import faiss  # moteur Facebook AI de recherche par similarité vectorielle (indexe et interroge de grands ensembles de vecteurs)

from langchain_community.vectorstores import FAISS  # wrapper LangChain autour de faiss, utilisé comme vector store dans la chaîne RAG

from langchain_huggingface import HuggingFaceEmbeddings  # génère les embeddings (vecteurs) du texte via un modèle Hugging Face / sentence-transformers

from mistralai.client import Mistral  # client officiel de l'API Mistral, utilisé pour la génération de la réponse (LLM) — mistralai 2.9.1 n'a pas de __init__.py racine, la classe vit dans le sous-module .client

import fastapi  # framework utilisé pour exposer le système RAG sous forme d'API REST

# %%
print("Python", sys.version)
print("faiss", faiss.__version__)
print("langchain_community.vectorstores.FAISS OK")
print("langchain_huggingface.HuggingFaceEmbeddings OK")
print("mistralai.Mistral OK")
print("fastapi", fastapi.__version__)
